# %%
import os
import pandas as pd
from xbrlassembler import XBRLAssembler

# %%
#Folder Path
current_path = os.getcwd()
combine_list = pd.read_csv('combine list.csv')
combine_list
# Out:
#       Unnamed: 0 Company                      Date  Tahun_Buku  \
# 0              0    AALI  24 Februari 2021 | 14:27        2020
# 1              1    ABBA   25 Agustus 2021 | 23:48        2020
# 2              2    ABDA     31 Maret 2021 | 16:50        2020
# 3              3    ABMM       31 Mei 2021 | 15:01        2020
# 4              4    ACES       06 Mei 2021 | 17:16        2020
# ...          ...     ...                       ...         ...
# 2243        2243    ZATA     03 April 2023 | 15:02        2022
# 2244        2244    ZBRA     10 April 2023 | 17:54        2022
# 2245        2245    ZINC      26 Juni 2023 | 21:49        2022
# 2246        2246    ZONE     03 April 2023 | 15:09        2022
# 2247        2247    ZYRX       02 Mei 2023 | 13:37        2022
#
#                                                    Link
# 0     https://www.idx.co.id/Portals/0/StaticData/Lis...
# 1     https://www.idx.co.id/Portals/0/StaticData/Lis...
# ...

# %%
AALI_2020_folder = os.path.join(current_path, 'Data','AALI','2020')
AALI_2020_PL = XBRLAssembler.from_dir(os.path.join(AALI_2020_folder))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\arsen\anaconda3\envs\binus\lib\site-packages\xbrlassembler\assembler.py:254, in XBRLAssembler.from_dir(cls, directory, ref_doc)
#     253 try:
# --> 254     return cls._init(file_map=file_map, ref_doc=ref_doc)
#     255 except KeyError as e:
#
# File c:\Users\arsen\anaconda3\envs\binus\lib\site-packages\xbrlassembler\assembler.py:208, in XBRLAssembler._init(cls, file_map, ref_doc)
#     199 """
#     200 Protected method to turn semi-organized xbrl data into a XBRLAssembler object.
#     201 This is required as the from_json constructor will populate the object without
#    (...)
#     206 :return: A complete `XBRLAssembler` with compiled data
#     207 """
# --> 208 schema = file_map[XBRLType.SCHEMA]
#     209 if not isinstance(schema, BeautifulSoup):
#
# KeyError: <XBRLType.SCHEMA: ('sch', 'xsd')>
#
# ...
