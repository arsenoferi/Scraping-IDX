# %%
import pandas as pd

# %%
data_raw = pd.read_csv('data_olahan_3.csv')
data_raw
# Out:
#      Company  Tahun_Buku        Tanggal Rilis           kas  \
# 0       NICK        2021  2022-03-14 10:08:00  1.151513e+10
# 1       AALI        2020  2021-02-24 14:27:00  9.788920e+05
# 2       ACST        2020  2021-02-24 14:37:00  7.340000e+04
# 3       ADMF        2020  2021-02-18 12:43:00  7.617200e+04
# 4       AMFG        2020  2021-04-16 16:16:00  2.989810e+05
# ...      ...         ...                  ...           ...
# 2368    ZINC        2022  2023-06-26 21:49:00  5.346490e+10
# 2369    ZONE        2022  2023-04-03 15:09:00  4.910326e+09
# 2370    ZYRX        2022  2023-05-02 13:37:00  2.063763e+11
# 2371    JKSW        2020  2021-06-04 08:54:00  8.820607e+09
# 2372    JKSW        2022  2023-04-12 18:25:00  1.014200e+10
#
#       jumlah_aset_lancar       piutang  jumlah_aset_tidak_lancar  \
# 0           3.043375e+11  1.000000e-06              1.096604e+10
# 1           5.937890e+06  1.513218e+06              2.184334e+07
# ...

# %%
data_raw = data_raw.sort_values(by=['EPS'], ascending=False)
