# %%
import pandas as pd
from pycaret.regression import *

# %%
data = pd.read_csv('data_olahan.csv')

# %%
data.columns
# Out:
# Index(['Company', 'Tahun_Buku', 'Tanggal Rilis', 'kas', 'jumlah_aset_lancar',
#        'piutang', 'jumlah_aset_tidak_lancar', 'jumlah_aset',
#        'jumlah_liabilitas_jangka_pendek', 'jumlah_liabilitas_jangka_panjang',
#        'jumlah_ekuitas', 'jumlah_liabilitas', 'pendapatan', 'cogs',
#        'laba_bruto', 'laba_rugi', 'laba_rugi_komprehensif', 'EPS', 'category',
#        '7D_Avg', 'per', 'current_ratio', 'cash_ratio', 'AR_Turnover',
#        'AR_Turnover_in_Days', 'Aset_Turnover', 'debt_to_equity',
#        'equity_ratio', 'debt_ratio', 'gpm', 'net_profit_margin', 'roa',
#        'roce'],
#       dtype='object')

# %%
data = data[['EPS', 'category','7D_Avg', 'per', 'current_ratio', 'cash_ratio', 'AR_Turnover','AR_Turnover_in_Days', 'Aset_Turnover', 'debt_to_equity','equity_ratio', 'debt_ratio', 'gpm', 'net_profit_margin', 'roa','roce']]

# %%
s = setup(data, target = 'per', session_id = 123)
# Out:
# <style type="text/css">
# #T_d471c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d471c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d471c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d471c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d471c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d471c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d471c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d471c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d471c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d471c_row1_col1" class="data row1 col1" >per</td>
#     </tr>
#     <tr>
#       <th id="T_d471c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:08:33
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_32cbf th {
#   text-align: left;
# }
# ...

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'error')

# %%
model = create_model('rf')
# Out:
# <style type="text/css">
# #T_aa658_row10_col0, #T_aa658_row10_col1, #T_aa658_row10_col2, #T_aa658_row10_col3, #T_aa658_row10_col4, #T_aa658_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_aa658">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa658_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_aa658_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_aa658_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_aa658_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_aa658_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_aa658_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_a816b_row10_col0, #T_a816b_row10_col1, #T_a816b_row10_col2, #T_a816b_row10_col3, #T_a816b_row10_col4, #T_a816b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a816b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a816b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a816b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a816b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a816b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a816b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a816b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
