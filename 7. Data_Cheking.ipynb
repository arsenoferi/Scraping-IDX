# %%
import pandas as pd

# %%
data = pd.read_csv('data_olahan.csv')
data = data[data['laba_rugi'].notna()]

# %%
data
# Out:
#      Company  Tahun_Buku        Tanggal Rilis           kas  \
# 0       BANK        2021  2022-03-31 17:47:00  2.240000e+02
# 1       LAPD        2021  2022-03-31 as:21:00  4.996100e+04
# 2       NICK        2021  2022-03-14 10:08:00  1.151513e+10
# 3       OASA        2021  2022-04-01 00:35:00  1.304324e+10
# 4       PLAN        2021  2022-04-30 15:28:00  1.129103e+08
# ...      ...         ...                  ...           ...
# 2228    ZINC        2022  2023-06-26 21:49:00  5.346490e+10
# 2229    ZONE        2022  2023-04-03 15:09:00  4.910326e+09
# 2230    ZYRX        2022  2023-05-02 13:37:00  2.063763e+11
# 2231    JKSW        2020  2021-06-04 08:54:00  8.820607e+09
# 2232    JKSW        2022  2023-04-12 18:25:00  1.014200e+10
#
#       jumlah_aset_lancar       piutang  jumlah_aset_tidak_lancar  \
# 0           2.056523e+06  1.000000e-06              1.166390e+05
# 1           4.996100e+04  1.000000e-06              2.797800e+04
# ...
