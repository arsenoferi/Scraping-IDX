# %%
import pandas as pd

# %% [markdown]
# # Load data_raw.csv

# %%
data = pd.read_csv('data_raw.csv')

data
# Out:
#      Company  Tahun_Buku        Tanggal Rilis           kas  \
# 0       AALI        2020  2021-02-24 14:27:00  9.788920e+05
# 1       ABBA        2020  2021-08-25 23:48:00  2.672453e+10
# 2       ABDA        2020  2021-03-31 16:50:00  6.520837e+08
# 3       ABMM        2020  2021-05-31 15:01:00  1.092124e+08
# 4       ACES        2020  2021-05-06 17:16:00  2.219785e+12
# ...      ...         ...                  ...           ...
# 2240    ZATA        2022  2023-04-03 15:02:00  2.447842e+10
# 2241    ZBRA        2022  2023-04-10 17:54:00  1.715849e+10
# 2242    ZINC        2022  2023-06-26 21:49:00  5.346490e+10
# 2243    ZONE        2022  2023-04-03 15:09:00  4.910326e+09
# 2244    ZYRX        2022  2023-05-02 13:37:00  2.063763e+11
#
#       jumlah_aset_lancar    persediaan       piutang  \
# 0           5.937890e+06  2.165603e+06  1.513218e+06
# 1           6.413759e+10  4.693148e+09  3.208438e+10
# 2           2.214891e+09           NaN  1.077348e+08
# ...

# %%
data = data[data.isna().any(axis=1)]
data
# Out:
#      Company  Tahun_Buku        Tanggal Rilis           kas  \
# 2       ABDA        2020  2021-03-31 16:50:00  6.520837e+08
# 15      AHAP        2020  2022-10-12 16:46:00  1.341178e+10
# 16      AIMS        2020  2021-03-16 19:34:00  6.851794e+07
# 21      AKSI        2020  2021-05-28 18:51:00  6.920995e+10
# 26      AMAG        2020  2021-03-31 12:49:00  1.002410e+09
# ...      ...         ...                  ...           ...
# 2240    ZATA        2022  2023-04-03 15:02:00  2.447842e+10
# 2241    ZBRA        2022  2023-04-10 17:54:00  1.715849e+10
# 2242    ZINC        2022  2023-06-26 21:49:00  5.346490e+10
# 2243    ZONE        2022  2023-04-03 15:09:00  4.910326e+09
# 2244    ZYRX        2022  2023-05-02 13:37:00  2.063763e+11
#
#       jumlah_aset_lancar  persediaan       piutang  jumlah_aset_tidak_lancar  \
# 2           2.214891e+09         NaN  1.077348e+08              2.628904e+08
# 15          5.060707e+11         NaN  1.553290e+11              2.371950e+10
# ...
